# %%
import pandas as pd

# %%
data=pd.read_csv("finalprojectdata.csv")

# %%
data
# Out:
#      Unnamed: 0                                         Brand Name     Cost  \
# 0             0                   realme C12 (Power Silver, 32 GB)   ₹7,999
# 1             1                     realme C12 (Power Blue, 32 GB)   ₹7,999
# 2             2                      POCO M3 (Power Black, 128 GB)  ₹11,999
# 3             3                   realme C12 (Power Silver, 64 GB)   ₹8,999
# 4             4                         REDMI 9i (Sea Blue, 64 GB)   ₹7,999
# ..          ...                                                ...      ...
# 400         400                                       Kechaoda K30   ₹1,049
# 401         401  Apple iPhone SE (Black, 256 GB) (Includes EarP...  ₹47,999
# 402         402                                 Nokia 3310 DS 2020   ₹3,540
# 403         403        SAMSUNG Galaxy A52 (Awesome Violet, 128 GB)  ₹27,999
# 404         404                    Redmi Note 6 Pro (Black, 64 GB)  ₹14,880
#
#             RAM  Rating Discount     Reviews
# ...

# %%
data = data.drop(['Unnamed: 0'], axis=1)

# %%
data.head()
# Out:
#                          Brand Name     Cost       RAM  Rating Discount  \
# 0  realme C12 (Power Silver, 32 GB)   ₹7,999  3 GB RAM     4.4  27% off
# 1    realme C12 (Power Blue, 32 GB)   ₹7,999  3 GB RAM     4.4  27% off
# 2     POCO M3 (Power Black, 128 GB)  ₹11,999  6 GB RAM     4.3  20% off
# 3  realme C12 (Power Silver, 64 GB)   ₹8,999  4 GB RAM     4.4  18% off
# 4        REDMI 9i (Sea Blue, 64 GB)   ₹7,999  4 GB RAM     4.3  20% off
#
#       Reviews
# 0  (2,44,869)
# 1  (2,44,869)
# 2    (71,679)
# 3     (7,649)
# 4  (2,35,321)

# %%
data.rename(columns={'Cost':'Price'},inplace=True)

# %%
data
# Out:
#                                             Brand Name    Price         RAM  \
# 0                     realme C12 (Power Silver, 32 GB)   ₹7,999    3 GB RAM
# 1                       realme C12 (Power Blue, 32 GB)   ₹7,999    3 GB RAM
# 2                        POCO M3 (Power Black, 128 GB)  ₹11,999    6 GB RAM
# 3                     realme C12 (Power Silver, 64 GB)   ₹8,999    4 GB RAM
# 4                           REDMI 9i (Sea Blue, 64 GB)   ₹7,999    4 GB RAM
# ..                                                 ...      ...         ...
# 400                                       Kechaoda K30   ₹1,049    8 GB RAM
# 401  Apple iPhone SE (Black, 256 GB) (Includes EarP...  ₹47,999    6 GB RAM
# 402                                 Nokia 3310 DS 2020   ₹3,540    Rosegold
# 403        SAMSUNG Galaxy A52 (Awesome Violet, 128 GB)  ₹27,999  WHITE GOLD
# 404                    Redmi Note 6 Pro (Black, 64 GB)  ₹14,880    4 GB RAM
#
#      Rating Discount     Reviews
# ...

# %%
data['Price'] = data['Price'].str.replace('₹', '')

# %%
data['Price'] = data['Price'].str.replace(',', '')

# %%
data['Discount'] = data['Discount'].str.replace('% off', '')

# %%
data
# Out:
#                                             Brand Name  Price         RAM  \
# 0                     realme C12 (Power Silver, 32 GB)   7999    3 GB RAM
# 1                       realme C12 (Power Blue, 32 GB)   7999    3 GB RAM
# 2                        POCO M3 (Power Black, 128 GB)  11999    6 GB RAM
# 3                     realme C12 (Power Silver, 64 GB)   8999    4 GB RAM
# 4                           REDMI 9i (Sea Blue, 64 GB)   7999    4 GB RAM
# ..                                                 ...    ...         ...
# 400                                       Kechaoda K30   1049    8 GB RAM
# 401  Apple iPhone SE (Black, 256 GB) (Includes EarP...  47999    6 GB RAM
# 402                                 Nokia 3310 DS 2020   3540    Rosegold
# 403        SAMSUNG Galaxy A52 (Awesome Violet, 128 GB)  27999  WHITE GOLD
# 404                    Redmi Note 6 Pro (Black, 64 GB)  14880    4 GB RAM
#
#      Rating Discount     Reviews
# 0       4.4       27  (2,44,869)
# ...

# %%
data['Reviews'] = data['Reviews'].str.replace('(', '')

# %%
data['Reviews'] = data['Reviews'].str.replace(')', '')

# %%
data['Reviews'] = data['Reviews'].str.replace(',', '')

# %%
import re
import numpy as np

# %%
ram = []
for val in data['RAM']:
    value = re.findall(r'\d',val)
    if value:
        ram.append(value)
    else:
        ram.append(np.NaN)

# %%
ram
# Out:
# [['3'],
#  ['3'],
#  ['6'],
#  ['4'],
#  ['4'],
#  ['4'],
#  ['6'],
#  ['4'],
#  ['8'],
#  ['6'],
#  ['6'],
#  ['3'],
#  ['3'],
#  ['2'],
#  ['2'],
#  ['4'],
#  ['4'],
#  ['4'],
#  ['4'],
#  ['4'],
#  ['4'],
#  ['2'],
#  ['2'],
#  ['6'],
#  ['4'],
#  ['4'],
#  ['6'],
#  ['4'],
#  ['8'],
#  ['2'],
#  ['4'],
#  ['4'],
#  ['4'],
#  ['4'],
#  ['3'],
#  ['4'],
#  ['4'],
#  ['8'],
#  ['8'],
#  ['8'],
#  ['4'],
#  ['8'],
#  nan,
#  ['4'],
#  ['3'],
#  ['3'],
#  ['4'],
#  ['6'],
#  nan,
#  ['6'],
#  ['4'],
#  ['4'],
#  nan,
#  ['3'],
#  ['2'],
#  ['2'],
#  ['3'],
#  ['4'],
#  ['3'],
#  ['3'],
#  ['3'],
#  ['3'],
#  ['8'],
#  ['3'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['6'],
#  ['3'],
#  ['8'],
#  ['4'],
#  ['6'],
#  ['6'],
#  ['3'],
#  ['4'],
#  ['6'],
#  ['6'],
#  ['4'],
#  nan,
#  ['6'],
#  ['4'],
#  nan,
#  ['2'],
#  nan,
#  nan,
#  ['6'],
#  ['6'],
#  ['6'],
#  nan,
#  ['4'],
#  ['6'],
#  ['4'],
#  nan,
#  ['6'],
#  nan,
#  ['8'],
#  ['6'],
#  ['4'],
#  nan,
#  ['8'],
#  ['6'],
# ...

# %%
data
# Out:
#                                             Brand Name  Price         RAM  \
# 0                     realme C12 (Power Silver, 32 GB)   7999    3 GB RAM
# 1                       realme C12 (Power Blue, 32 GB)   7999    3 GB RAM
# 2                        POCO M3 (Power Black, 128 GB)  11999    6 GB RAM
# 3                     realme C12 (Power Silver, 64 GB)   8999    4 GB RAM
# 4                           REDMI 9i (Sea Blue, 64 GB)   7999    4 GB RAM
# ..                                                 ...    ...         ...
# 400                                       Kechaoda K30   1049    8 GB RAM
# 401  Apple iPhone SE (Black, 256 GB) (Includes EarP...  47999    6 GB RAM
# 402                                 Nokia 3310 DS 2020   3540    Rosegold
# 403        SAMSUNG Galaxy A52 (Awesome Violet, 128 GB)  27999  WHITE GOLD
# 404                    Redmi Note 6 Pro (Black, 64 GB)  14880    4 GB RAM
#
#      Rating Discount Reviews
# 0       4.4       27  244869
# ...

# %%
data
# Out:
#                                             Brand Name  Price         RAM  \
# 0                     realme C12 (Power Silver, 32 GB)   7999    3 GB RAM
# 1                       realme C12 (Power Blue, 32 GB)   7999    3 GB RAM
# 2                        POCO M3 (Power Black, 128 GB)  11999    6 GB RAM
# 3                     realme C12 (Power Silver, 64 GB)   8999    4 GB RAM
# 4                           REDMI 9i (Sea Blue, 64 GB)   7999    4 GB RAM
# ..                                                 ...    ...         ...
# 400                                       Kechaoda K30   1049    8 GB RAM
# 401  Apple iPhone SE (Black, 256 GB) (Includes EarP...  47999    6 GB RAM
# 402                                 Nokia 3310 DS 2020   3540    Rosegold
# 403        SAMSUNG Galaxy A52 (Awesome Violet, 128 GB)  27999  WHITE GOLD
# 404                    Redmi Note 6 Pro (Black, 64 GB)  14880    4 GB RAM
#
#      Rating Discount Reviews
# 0       4.4       27  244869
# ...

# %%
data["RAM( in gb)"]=ram

# %%
data
# Out:
#                                             Brand Name  Price         RAM  \
# 0                     realme C12 (Power Silver, 32 GB)   7999    3 GB RAM
# 1                       realme C12 (Power Blue, 32 GB)   7999    3 GB RAM
# 2                        POCO M3 (Power Black, 128 GB)  11999    6 GB RAM
# 3                     realme C12 (Power Silver, 64 GB)   8999    4 GB RAM
# 4                           REDMI 9i (Sea Blue, 64 GB)   7999    4 GB RAM
# ..                                                 ...    ...         ...
# 400                                       Kechaoda K30   1049    8 GB RAM
# 401  Apple iPhone SE (Black, 256 GB) (Includes EarP...  47999    6 GB RAM
# 402                                 Nokia 3310 DS 2020   3540    Rosegold
# 403        SAMSUNG Galaxy A52 (Awesome Violet, 128 GB)  27999  WHITE GOLD
# 404                    Redmi Note 6 Pro (Black, 64 GB)  14880    4 GB RAM
#
#      Rating Discount Reviews RAM( in gb)
# ...

# %%
data['Brand'] = data['Brand Name'].apply(lambda x: x.split('(')[0])
data.head()
# Out:
#                          Brand Name  Price       RAM  Rating Discount Reviews  \
# 0  realme C12 (Power Silver, 32 GB)   7999  3 GB RAM     4.4       27  244869
# 1    realme C12 (Power Blue, 32 GB)   7999  3 GB RAM     4.4       27  244869
# 2     POCO M3 (Power Black, 128 GB)  11999  6 GB RAM     4.3       20   71679
# 3  realme C12 (Power Silver, 64 GB)   8999  4 GB RAM     4.4       18    7649
# 4        REDMI 9i (Sea Blue, 64 GB)   7999  4 GB RAM     4.3       20  235321
#
#   RAM( in gb)        Brand
# 0         [3]  realme C12
# 1         [3]  realme C12
# 2         [6]     POCO M3
# 3         [4]  realme C12
# 4         [4]    REDMI 9i

# %%
color = []
for x in data['Brand Name']:
    if '(' in x:
        color.append(x.split('(')[1])
    else:
        color.append(np.NaN)

# %%
color
# Out:
# ['Power Silver, 32 GB)',
#  'Power Blue, 32 GB)',
#  'Power Black, 128 GB)',
#  'Power Silver, 64 GB)',
#  'Sea Blue, 64 GB)',
#  'Space Blue, 64 GB)',
#  'Cool Blue, 64 GB)',
#  'Midnight Black, 64 GB)',
#  'Mist Blue, 128 GB)',
#  'Mist White, 64 GB)',
#  'Mist Blue, 64 GB)',
#  'Laser Black, 32 GB)',
#  'Laser Blue, 32 GB)',
#  'Obsidian Black, 32 GB)',
#  'Quartz Green, 32 GB)',
#  'Fusion Blue, 64 GB)',
#  'Fusion Green, 64 GB)',
#  'Victory Blue, 128 GB)',
#  'Victory Blue, 64 GB)',
#  'Glory Silver, 64 GB)',
#  'Glory Silver, 128 GB)',
#  'Red, 32 GB)',
#  'Royal Blue, 32 GB)',
#  'Power Black, 64 GB)',
#  'Nature Green, 64 GB)',
#  'White, 64 GB)',
#  'Blazing Blue, 64 GB)',
#  'Yellow, 64 GB)',
#  'Fusion Green, 128 GB)',
#  'Mist White, 128 GB)',
#  'Black, 32 GB)',
#  'Power Silver, 64 GB)',
#  'Power Blue, 64 GB)',
#  'Arctic Blue, 64 GB)',
#  'Matte Black, 64 GB)',
#  'Arctic Blue, 32 GB)',
#  'Power Blue, 64 GB)',
#  'Power Silver, 64 GB)',
#  'Cyber Silver, 128 GB)',
# ...

# %%
color[0].split(',')[0]
# Out:
# 'Power Silver'

# %%
color1 = []
for i in color:
    color1.append(str(i).split(',')[0])

# %%
data['color'] = color1

# %%
data.head()
# Out:
#                          Brand Name  Price       RAM  Rating Discount Reviews  \
# 0  realme C12 (Power Silver, 32 GB)   7999  3 GB RAM     4.4       27  244869
# 1    realme C12 (Power Blue, 32 GB)   7999  3 GB RAM     4.4       27  244869
# 2     POCO M3 (Power Black, 128 GB)  11999  6 GB RAM     4.3       20   71679
# 3  realme C12 (Power Silver, 64 GB)   8999  4 GB RAM     4.4       18    7649
# 4        REDMI 9i (Sea Blue, 64 GB)   7999  4 GB RAM     4.3       20  235321
#
#   RAM( in gb)        Brand         color
# 0         [3]  realme C12   Power Silver
# 1         [3]  realme C12     Power Blue
# 2         [6]     POCO M3    Power Black
# 3         [4]  realme C12   Power Silver
# 4         [4]    REDMI 9i       Sea Blue

# %%
data.drop("RAM",axis=1,inplace=True)
#data.drop("RAM_gb",axis=1,inplace=True)

# %%
data
# Out:
#                                             Brand Name  Price  Rating  \
# 0                     realme C12 (Power Silver, 32 GB)   7999     4.4
# 1                       realme C12 (Power Blue, 32 GB)   7999     4.4
# 2                        POCO M3 (Power Black, 128 GB)  11999     4.3
# 3                     realme C12 (Power Silver, 64 GB)   8999     4.4
# 4                           REDMI 9i (Sea Blue, 64 GB)   7999     4.3
# ..                                                 ...    ...     ...
# 400                                       Kechaoda K30   1049     4.0
# 401  Apple iPhone SE (Black, 256 GB) (Includes EarP...  47999     4.5
# 402                                 Nokia 3310 DS 2020   3540     3.8
# 403        SAMSUNG Galaxy A52 (Awesome Violet, 128 GB)  27999     4.5
# 404                    Redmi Note 6 Pro (Black, 64 GB)  14880     4.5
#
#     Discount Reviews RAM( in gb)                Brand           color
# ...

# %%
data
# Out:
#                                             Brand Name  Price  Rating  \
# 0                     realme C12 (Power Silver, 32 GB)   7999     4.4
# 1                       realme C12 (Power Blue, 32 GB)   7999     4.4
# 2                        POCO M3 (Power Black, 128 GB)  11999     4.3
# 3                     realme C12 (Power Silver, 64 GB)   8999     4.4
# 4                           REDMI 9i (Sea Blue, 64 GB)   7999     4.3
# ..                                                 ...    ...     ...
# 400                                       Kechaoda K30   1049     4.0
# 401  Apple iPhone SE (Black, 256 GB) (Includes EarP...  47999     4.5
# 402                                 Nokia 3310 DS 2020   3540     3.8
# 403        SAMSUNG Galaxy A52 (Awesome Violet, 128 GB)  27999     4.5
# 404                    Redmi Note 6 Pro (Black, 64 GB)  14880     4.5
#
#     Discount Reviews RAM( in gb)                Brand           color
# ...

# %% [markdown]
# ## Changing object to numeric

# %%
data['Price'] = pd.to_numeric(data['Price'],errors = 'coerce')

# %%
data['Reviews'] = pd.to_numeric(data['Reviews'],errors = 'coerce')

# %%
data['Discount'] = pd.to_numeric(data['Discount'],errors = 'coerce')

# %%
import re

# %%
rom = []
for i in data['Brand Name']:
    if 'GB' in i:
        rom.append(re.findall(r'(\d+)\sGB',str(i)))
    else:
        rom.append(np.nan)

# %%
rom
# Out:
# [['32'],
#  ['32'],
#  ['128'],
#  ['64'],
#  ['64'],
#  ['64'],
#  ['64'],
#  ['64'],
#  ['128'],
#  ['64'],
#  ['64'],
#  ['32'],
#  ['32'],
#  ['32'],
#  ['32'],
#  ['64'],
#  ['64'],
#  ['128'],
#  ['64'],
#  ['64'],
#  ['128'],
#  ['32'],
#  ['32'],
#  ['64'],
#  ['64'],
#  ['64'],
#  ['64'],
#  ['64'],
#  ['128'],
#  ['128'],
#  ['32'],
#  ['64'],
#  ['64'],
#  ['64'],
#  ['64'],
#  ['32'],
#  ['64'],
#  ['64'],
#  ['128'],
#  ['128'],
#  ['128'],
#  ['128'],
#  nan,
#  ['64'],
#  ['32'],
#  ['32'],
#  ['64'],
#  ['128'],
#  nan,
#  ['128'],
#  ['64'],
#  ['64'],
#  nan,
#  ['32'],
#  ['32'],
#  ['32'],
#  ['32'],
#  ['64'],
#  ['32'],
#  ['32'],
#  ['32'],
#  ['32'],
#  ['64'],
#  ['128'],
#  ['64'],
#  ['32'],
#  ['32'],
#  ['32'],
#  ['32'],
#  ['32'],
#  ['128'],
#  ['32'],
#  ['128'],
#  ['64'],
#  ['64'],
#  ['64'],
#  ['64'],
#  ['128'],
#  ['64'],
#  nan,
#  ['128'],
#  ['64'],
#  nan,
#  ['32'],
#  nan,
#  nan,
#  ['128'],
#  ['128'],
#  ['64'],
#  nan,
#  ['64'],
# ...

# %%
data["ROM"]=rom

# %%
data
# Out:
#                                             Brand Name  Price  Rating  \
# 0                     realme C12 (Power Silver, 32 GB)   7999     4.4
# 1                       realme C12 (Power Blue, 32 GB)   7999     4.4
# 2                        POCO M3 (Power Black, 128 GB)  11999     4.3
# 3                     realme C12 (Power Silver, 64 GB)   8999     4.4
# 4                           REDMI 9i (Sea Blue, 64 GB)   7999     4.3
# ..                                                 ...    ...     ...
# 400                                       Kechaoda K30   1049     4.0
# 401  Apple iPhone SE (Black, 256 GB) (Includes EarP...  47999     4.5
# 402                                 Nokia 3310 DS 2020   3540     3.8
# 403        SAMSUNG Galaxy A52 (Awesome Violet, 128 GB)  27999     4.5
# 404                    Redmi Note 6 Pro (Black, 64 GB)  14880     4.5
#
#      Discount  Reviews RAM( in gb)                Brand           color    ROM
# ...

# %%
data
# Out:
#                                             Brand Name  Price  Rating  \
# 0                     realme C12 (Power Silver, 32 GB)   7999     4.4
# 1                       realme C12 (Power Blue, 32 GB)   7999     4.4
# 2                        POCO M3 (Power Black, 128 GB)  11999     4.3
# 3                     realme C12 (Power Silver, 64 GB)   8999     4.4
# 4                           REDMI 9i (Sea Blue, 64 GB)   7999     4.3
# ..                                                 ...    ...     ...
# 400                                       Kechaoda K30   1049     4.0
# 401  Apple iPhone SE (Black, 256 GB) (Includes EarP...  47999     4.5
# 402                                 Nokia 3310 DS 2020   3540     3.8
# 403        SAMSUNG Galaxy A52 (Awesome Violet, 128 GB)  27999     4.5
# 404                    Redmi Note 6 Pro (Black, 64 GB)  14880     4.5
#
#      Discount  Reviews RAM( in gb)                Brand           color    ROM
# ...

# %%
  

new = data["Brand Name"].str.split(" ", n = 1, expand = True)
  
#
data["Brand_Name"]= new[0]
  
# making separate last name column from new data frame
#data["Last Name"]= new[1]
  
# Dropping old Name columns
data.drop(columns =["Brand"], inplace = True)
  
# df display
data
# Out:
#                                             Brand Name  Price  Rating  \
# 0                     realme C12 (Power Silver, 32 GB)   7999     4.4
# 1                       realme C12 (Power Blue, 32 GB)   7999     4.4
# 2                        POCO M3 (Power Black, 128 GB)  11999     4.3
# 3                     realme C12 (Power Silver, 64 GB)   8999     4.4
# 4                           REDMI 9i (Sea Blue, 64 GB)   7999     4.3
# ..                                                 ...    ...     ...
# 400                                       Kechaoda K30   1049     4.0
# 401  Apple iPhone SE (Black, 256 GB) (Includes EarP...  47999     4.5
# 402                                 Nokia 3310 DS 2020   3540     3.8
# 403        SAMSUNG Galaxy A52 (Awesome Violet, 128 GB)  27999     4.5
# 404                    Redmi Note 6 Pro (Black, 64 GB)  14880     4.5
#
#      Discount  Reviews RAM( in gb)           color    ROM Brand_Name
# ...

# %%
# data.drop("Brand Name",axis=1,inplace=True)

# %%
data
# Out:
#                                             Brand Name  Price  Rating  \
# 0                     realme C12 (Power Silver, 32 GB)   7999     4.4
# 1                       realme C12 (Power Blue, 32 GB)   7999     4.4
# 2                        POCO M3 (Power Black, 128 GB)  11999     4.3
# 3                     realme C12 (Power Silver, 64 GB)   8999     4.4
# 4                           REDMI 9i (Sea Blue, 64 GB)   7999     4.3
# ..                                                 ...    ...     ...
# 400                                       Kechaoda K30   1049     4.0
# 401  Apple iPhone SE (Black, 256 GB) (Includes EarP...  47999     4.5
# 402                                 Nokia 3310 DS 2020   3540     3.8
# 403        SAMSUNG Galaxy A52 (Awesome Violet, 128 GB)  27999     4.5
# 404                    Redmi Note 6 Pro (Black, 64 GB)  14880     4.5
#
#      Discount  Reviews RAM( in gb)           color    ROM Brand_Name
# ...

# %%
a=[8]
a[0]
# Out:
# 8

# %%
k=data['RAM( in gb)']
l1=[]
#print(k)
for i in k:
    if type(i)==list:
        l1.append(i[0])
    else:
        l1.append(np.nan)
#print(type(l1[0])) 
#type(int(l1[0]))

# %%
data['RAM( in gb)']=l1

# %%
data
# Out:
#                                             Brand Name  Price  Rating  \
# 0                     realme C12 (Power Silver, 32 GB)   7999     4.4
# 1                       realme C12 (Power Blue, 32 GB)   7999     4.4
# 2                        POCO M3 (Power Black, 128 GB)  11999     4.3
# 3                     realme C12 (Power Silver, 64 GB)   8999     4.4
# 4                           REDMI 9i (Sea Blue, 64 GB)   7999     4.3
# ..                                                 ...    ...     ...
# 400                                       Kechaoda K30   1049     4.0
# 401  Apple iPhone SE (Black, 256 GB) (Includes EarP...  47999     4.5
# 402                                 Nokia 3310 DS 2020   3540     3.8
# 403        SAMSUNG Galaxy A52 (Awesome Violet, 128 GB)  27999     4.5
# 404                    Redmi Note 6 Pro (Black, 64 GB)  14880     4.5
#
#      Discount  Reviews RAM( in gb)           color    ROM Brand_Name
# ...

# %%
k=data['ROM']
l2=[]
#print(k)
for i in k:
    if type(i)==list:
        l2.append(i[0])
    else:
        l2.append(np.nan)
#print(type(l1[0])) 
#type(int(l1[0]))

# %%
data['ROM']=l2

# %%
data
# Out:
#                                             Brand Name  Price  Rating  \
# 0                     realme C12 (Power Silver, 32 GB)   7999     4.4
# 1                       realme C12 (Power Blue, 32 GB)   7999     4.4
# 2                        POCO M3 (Power Black, 128 GB)  11999     4.3
# 3                     realme C12 (Power Silver, 64 GB)   8999     4.4
# 4                           REDMI 9i (Sea Blue, 64 GB)   7999     4.3
# ..                                                 ...    ...     ...
# 400                                       Kechaoda K30   1049     4.0
# 401  Apple iPhone SE (Black, 256 GB) (Includes EarP...  47999     4.5
# 402                                 Nokia 3310 DS 2020   3540     3.8
# 403        SAMSUNG Galaxy A52 (Awesome Violet, 128 GB)  27999     4.5
# 404                    Redmi Note 6 Pro (Black, 64 GB)  14880     4.5
#
#      Discount  Reviews RAM( in gb)           color  ROM Brand_Name
# ...

# %%
data['RAM( in gb)']=data['RAM( in gb)'].fillna("0")

# %%
data.head()
# Out:
#                          Brand Name  Price  Rating  Discount  Reviews  \
# 0  realme C12 (Power Silver, 32 GB)   7999     4.4        27   244869
# 1    realme C12 (Power Blue, 32 GB)   7999     4.4        27   244869
# 2     POCO M3 (Power Black, 128 GB)  11999     4.3        20    71679
# 3  realme C12 (Power Silver, 64 GB)   8999     4.4        18     7649
# 4        REDMI 9i (Sea Blue, 64 GB)   7999     4.3        20   235321
#
#   RAM( in gb)         color  ROM Brand_Name
# 0           3  Power Silver   32     realme
# 1           3    Power Blue   32     realme
# 2           6   Power Black  128       POCO
# 3           4  Power Silver   64     realme
# 4           4      Sea Blue   64      REDMI

# %%
data['ROM']=data['ROM'].fillna("0")

# %%
data
# Out:
#                                             Brand Name  Price  Rating  \
# 0                     realme C12 (Power Silver, 32 GB)   7999     4.4
# 1                       realme C12 (Power Blue, 32 GB)   7999     4.4
# 2                        POCO M3 (Power Black, 128 GB)  11999     4.3
# 3                     realme C12 (Power Silver, 64 GB)   8999     4.4
# 4                           REDMI 9i (Sea Blue, 64 GB)   7999     4.3
# ..                                                 ...    ...     ...
# 400                                       Kechaoda K30   1049     4.0
# 401  Apple iPhone SE (Black, 256 GB) (Includes EarP...  47999     4.5
# 402                                 Nokia 3310 DS 2020   3540     3.8
# 403        SAMSUNG Galaxy A52 (Awesome Violet, 128 GB)  27999     4.5
# 404                    Redmi Note 6 Pro (Black, 64 GB)  14880     4.5
#
#      Discount  Reviews RAM( in gb)           color  ROM Brand_Name
# ...

# %%
for i in data['RAM( in gb)']:
    print(i)
# Out:
# 3
# 3
# 6
# 4
# 4
# 4
# 6
# 4
# 8
# 6
# 6
# 3
# 3
# 2
# 2
# 4
# 4
# 4
# 4
# 4
# 4
# 2
# 2
# 6
# 4
# 4
# 6
# 4
# 8
# 2
# 4
# 4
# 4
# 4
# 3
# 4
# 4
# 8
# 8
# 8
# 4
# 8
# 0
# 4
# 3
# 3
# 4
# 6
# 0
# 6
# 4
# 4
# 0
# 3
# 2
# 2
# 3
# 4
# 3
# 3
# 3
# 3
# 8
# 3
# 2
# 2
# 2
# 2
# 6
# 3
# 8
# 4
# 6
# 6
# 3
# 4
# 6
# 6
# 4
# 0
# 6
# 4
# 0
# 2
# 0
# 0
# 6
# 6
# 6
# 0
# 4
# 6
# 4
# 0
# 6
# 0
# 8
# 6
# 4
# 0
# 8
# 6
# 8
# 6
# 8
# 6
# 4
# 4
# 4
# 4
# 0
# 0
# 3
# 3
# 0
# 0
# 0
# 0
# 6
# 0
# 0
# 0
# 4
# 4
# 2
# 4
# 3
# 6
# 4
# 0
# 8
# 0
# 3
# 6
# 6
# 8
# 8
# 4
# 2
# 4
# 6
# 6
# 0
# 0
# 0
# 4
# 0
# 6
# 0
# 4
# 0
# 6
# 6
# 4
# 0
# 3
# 8
# 2
# 2
# 4
# 0
# 0
# 0
# 0
# 0
# 0
# 4
# 4
# 4
# 4
# 4
# 4
# 6
# 6
# 0
# 6
# 0
# 0
# 4
# 4
# 4
# 8
# 6
# 0
# 0
# 0
# 0
# 0
# 4
# 0
# 6
# 0
# 6
# 0
# 0
# 3
# 4
# 6
# 0
# 0
# 2
# 4
# 4
# 0
# 0
# 6
# 4
# 6
# 0
# 6
# 0
# 0
# 0
# 0
# 0
# 0
# 0
# 0
# 0
# 3
# 0
# 8
# 0
# 6
# 0
# 4
# 6
# 8
# 0
# 0
# 8
# 0
# 6
# 8
# 0
# 0
# 0
# 3
# 0
# 0
# 0
# 0
# 3
# 4
# 8
# 3
# 0
# 3
# 0
# 4
# ...

# %%
data['Phone Name'] = data['Brand Name'].apply(lambda x: x.split('(')[0])
data.head()
# Out:
#                          Brand Name  Price  Rating  Discount  Reviews  \
# 0  realme C12 (Power Silver, 32 GB)   7999     4.4        27   244869
# 1    realme C12 (Power Blue, 32 GB)   7999     4.4        27   244869
# 2     POCO M3 (Power Black, 128 GB)  11999     4.3        20    71679
# 3  realme C12 (Power Silver, 64 GB)   8999     4.4        18     7649
# 4        REDMI 9i (Sea Blue, 64 GB)   7999     4.3        20   235321
#
#   RAM( in gb)         color  ROM Brand_Name   Phone Name
# 0           3  Power Silver   32     realme  realme C12
# 1           3    Power Blue   32     realme  realme C12
# 2           6   Power Black  128       POCO     POCO M3
# 3           4  Power Silver   64     realme  realme C12
# 4           4      Sea Blue   64      REDMI    REDMI 9i

# %%
data
# Out:
#                                             Brand Name  Price  Rating  \
# 0                     realme C12 (Power Silver, 32 GB)   7999     4.4
# 1                       realme C12 (Power Blue, 32 GB)   7999     4.4
# 2                        POCO M3 (Power Black, 128 GB)  11999     4.3
# 3                     realme C12 (Power Silver, 64 GB)   8999     4.4
# 4                           REDMI 9i (Sea Blue, 64 GB)   7999     4.3
# ..                                                 ...    ...     ...
# 400                                       Kechaoda K30   1049     4.0
# 401  Apple iPhone SE (Black, 256 GB) (Includes EarP...  47999     4.5
# 402                                 Nokia 3310 DS 2020   3540     3.8
# 403        SAMSUNG Galaxy A52 (Awesome Violet, 128 GB)  27999     4.5
# 404                    Redmi Note 6 Pro (Black, 64 GB)  14880     4.5
#
#      Discount  Reviews RAM( in gb)           color  ROM Brand_Name  \
# ...

# %%
data.rename({'Brand Name': 'Product_Info',}, axis=1, inplace=True)

# %%
data
# Out:
#                                           Product_Info  Price  Rating  \
# 0                     realme C12 (Power Silver, 32 GB)   7999     4.4
# 1                       realme C12 (Power Blue, 32 GB)   7999     4.4
# 2                        POCO M3 (Power Black, 128 GB)  11999     4.3
# 3                     realme C12 (Power Silver, 64 GB)   8999     4.4
# 4                           REDMI 9i (Sea Blue, 64 GB)   7999     4.3
# ..                                                 ...    ...     ...
# 400                                       Kechaoda K30   1049     4.0
# 401  Apple iPhone SE (Black, 256 GB) (Includes EarP...  47999     4.5
# 402                                 Nokia 3310 DS 2020   3540     3.8
# 403        SAMSUNG Galaxy A52 (Awesome Violet, 128 GB)  27999     4.5
# 404                    Redmi Note 6 Pro (Black, 64 GB)  14880     4.5
#
#      Discount  Reviews RAM( in gb)           color  ROM Brand_Name  \
# ...

# %%
data.drop("Product_Info",axis=1,inplace=True)

# %%
data
# Out:
#      Price  Rating  Discount  Reviews RAM( in gb)           color  ROM  \
# 0     7999     4.4        27   244869           3    Power Silver   32
# 1     7999     4.4        27   244869           3      Power Blue   32
# 2    11999     4.3        20    71679           6     Power Black  128
# 3     8999     4.4        18     7649           4    Power Silver   64
# 4     7999     4.3        20   235321           4        Sea Blue   64
# ..     ...     ...       ...      ...         ...             ...  ...
# 400   1049     4.0         5      412           8             nan    0
# 401  47999     4.5        12    95186           6           Black  256
# 402   3540     3.8         6    29981           0             nan    0
# 403  27999     4.5        16       15           0  Awesome Violet  128
# 404  14880     4.5         5   126419           4           Black   64
#
#     Brand_Name           Phone Name
# 0       realme          realme C12
# 1       realme          realme C12
# ...

# %%
data=data.reindex(columns= ["Brand_Name","Phone Name","Price","Rating","Discount","Reviews","RAM( in gb)","ROM","color","Top_Rating"])

# %%
data
# Out:
#     Brand_Name           Phone Name  Price  Rating  Discount  Reviews  \
# 0       realme          realme C12    7999     4.4        27   244869
# 1       realme          realme C12    7999     4.4        27   244869
# 2         POCO             POCO M3   11999     4.3        20    71679
# 3       realme          realme C12    8999     4.4        18     7649
# 4        REDMI            REDMI 9i    7999     4.3        20   235321
# ..         ...                  ...    ...     ...       ...      ...
# 400   Kechaoda         Kechaoda K30   1049     4.0         5      412
# 401      Apple     Apple iPhone SE   47999     4.5        12    95186
# 402      Nokia   Nokia 3310 DS 2020   3540     3.8         6    29981
# 403    SAMSUNG  SAMSUNG Galaxy A52   27999     4.5        16       15
# 404      Redmi    Redmi Note 6 Pro   14880     4.5         5   126419
#
#     RAM( in gb)  ROM           color  Top_Rating
# 0             3   32    Power Silver         NaN
# ...

# %%
data['Top_Rating']=data.Rating.apply(lambda x:"Good" if x>=4 else "Average")

# %%
data
# Out:
#     Brand_Name           Phone Name  Price  Rating  Discount  Reviews  \
# 0       realme          realme C12    7999     4.4        27   244869
# 1       realme          realme C12    7999     4.4        27   244869
# 2         POCO             POCO M3   11999     4.3        20    71679
# 3       realme          realme C12    8999     4.4        18     7649
# 4        REDMI            REDMI 9i    7999     4.3        20   235321
# ..         ...                  ...    ...     ...       ...      ...
# 400   Kechaoda         Kechaoda K30   1049     4.0         5      412
# 401      Apple     Apple iPhone SE   47999     4.5        12    95186
# 402      Nokia   Nokia 3310 DS 2020   3540     3.8         6    29981
# 403    SAMSUNG  SAMSUNG Galaxy A52   27999     4.5        16       15
# 404      Redmi    Redmi Note 6 Pro   14880     4.5         5   126419
#
#     RAM( in gb)  ROM           color Top_Rating
# 0             3   32    Power Silver       Good
# ...

# %%
gr = data.groupby('Brand_Name')

# %%
gr.first()
# Out:
#                                                    Phone Name  Price  Rating  \
# Brand_Name
# APPLE                                        APPLE iPhone 11   51999     4.6
# Apple                                        Apple iPhone XR   41999     4.6
# BlackBear                              BlackBear A1 Pen Phone   1899     3.5
# BlackZone                                 BlackZone TURBO 353    849     4.0
# CALLBAR                                      CALLBAR Bold 312    620     3.7
# ENERGIZER                                ENERGIZER Energy E20   1599     3.7
# Easyfone                                        Easyfone Star   3499     4.2
# GFive                                              GFive U873    669     3.7
# GIONEE                                            GIONEE Max    5499     4.1
# GREENBERRI                                      GREENBERRI F1   1450     4.2
# Geotel                                         Geotel K9 Flip   1349     3.8
# ...

# %%
grb = data.groupby(['Brand_Name','Phone Name'])

# %%
grb.first()
# Out:
#                                     Price  Rating  Discount  Reviews  \
# Brand_Name Phone Name
# APPLE      APPLE iPhone 11          51999     4.6         5    41515
#            APPLE iPhone 12          76900     4.6         1     2028
#            APPLE iPhone 12 Mini     65900     4.5        20      684
# Apple      Apple iPhone SE          47999     4.5        12    95186
#            Apple iPhone XR          41999     4.6        21    78966
# ...                                   ...     ...       ...      ...
# realme     realme Narzo 20A          9499     4.4        20   174337
#            realme Narzo 30 Pro 5G   16999     4.4        19    42440
#            realme Narzo 30A          8999     4.5        10     9051
#            realme X3 SuperZoom      32999     4.3         5     2027
#            realme X7 5G             19999     4.4        23     7723
#
#                                    RAM( in gb)  ROM         color Top_Rating
# Brand_Name Phone Name
# ...

# %% [markdown]
# # Brand which have above 4.5 rating(High ratings brands)

# %%
data[(data.Rating>4.5)]
# Out:
#     Brand_Name         Phone Name  Price  Rating  Discount  Reviews  \
# 25       APPLE   APPLE iPhone 11   51999     4.6         5    41515
# 62       APPLE   APPLE iPhone 11   51999     4.6         5    41700
# 64       APPLE   APPLE iPhone 11   51999     4.6        20    41700
# 74       Apple   Apple iPhone XR   41999     4.6        21    78966
# 122      APPLE   APPLE iPhone 11   56999     4.6         2    41825
# 231      Apple   Apple iPhone XR   46999     4.6        15    79026
# 267    Snexian  Snexian guru 5500    899     5.0         3        4
# 301      APPLE   APPLE iPhone 11   51999     4.6        25    41973
# 347      APPLE   APPLE iPhone 12   76900     4.6         1     2028
# 352      Apple   Apple iPhone XR   46999     4.6        10    79050
# 354      APPLE   APPLE iPhone 12   76900     4.6        20     2028
# 373      APPLE   APPLE iPhone 12   81900     4.6         1     2030
# 393      Apple   Apple iPhone XR   41999     4.6        22    79050
#
# ...

# %% [markdown]
# # Observation
# * apple iphone 11 is highest rated phone but senexian guru is most highest rated phone.
# - Apple phones are highest rated phones.
# - Apple iPhone XR
# - ratings are good

# %% [markdown]
# # Products having large discount above

# %%
data[(data.Discount>30)]
# Out:
#     Brand_Name           Phone Name  Price  Rating  Discount  Reviews  \
# 21      GIONEE          GIONEE Max    5499     4.1        31    51140
# 22      GIONEE          GIONEE Max    5499     4.1        31    51139
# 30      GIONEE          GIONEE Max    5499     4.1        31    51140
# 182    SAMSUNG  SAMSUNG Galaxy F41   15499     4.3        48   246729
# 205     realme        realme 7 Pro   19999     4.4        35    73647
# 256    SAMSUNG  SAMSUNG Galaxy M02    7410     4.1        40      177
# 397       OPPO        OPPO F17 Pro   21490     4.4        37     7630
#
#     RAM( in gb)  ROM         color Top_Rating
# 21            2   32           Red       Good
# 22            2   32    Royal Blue       Good
# 30            4   32         Black       Good
# 182           6   64  Fusion Black       Good
# 205           6  128   Mirror Blue       Good
# 256           2   32          Gray       Good
# 397           4  128   Matte Black       Good

# %% [markdown]
# # Obsevevation
# - SAMSUNG Galaxy F41 (Fusion Black, 64 GB) have highest 48% discount.
# - All the phones have above 4.0 ratings.
# -

# %% [markdown]
# # Top Rating

# %%
data['Top_Rating']=data.Rating.apply(lambda x:"Good" if x>=4 else "Avg ")

# %%
data
# Out:
#     Brand_Name           Phone Name  Price  Rating  Discount  Reviews  \
# 0       realme          realme C12    7999     4.4        27   244869
# 1       realme          realme C12    7999     4.4        27   244869
# 2         POCO             POCO M3   11999     4.3        20    71679
# 3       realme          realme C12    8999     4.4        18     7649
# 4        REDMI            REDMI 9i    7999     4.3        20   235321
# ..         ...                  ...    ...     ...       ...      ...
# 400   Kechaoda         Kechaoda K30   1049     4.0         5      412
# 401      Apple     Apple iPhone SE   47999     4.5        12    95186
# 402      Nokia   Nokia 3310 DS 2020   3540     3.8         6    29981
# 403    SAMSUNG  SAMSUNG Galaxy A52   27999     4.5        16       15
# 404      Redmi    Redmi Note 6 Pro   14880     4.5         5   126419
#
#     RAM( in gb)  ROM           color Top_Rating
# 0             3   32    Power Silver       Good
# ...

# %% [markdown]
# # Data Analysis
# - Uni-variate Analysis
# - Bi-variate Analysis
# - Multi-variate Analysis using Group by concept and describing the statistical
# - analysis

# %% [markdown]
# # Top five highest discount mobile phones

# %%
fivedis=data.nlargest(5, ['Discount'])

# %%
fivedis
# Out:
#     Brand_Name           Phone Name  Price  Rating  Discount  Reviews  \
# 182    SAMSUNG  SAMSUNG Galaxy F41   15499     4.3        48   246729
# 256    SAMSUNG  SAMSUNG Galaxy M02    7410     4.1        40      177
# 397       OPPO        OPPO F17 Pro   21490     4.4        37     7630
# 205     realme        realme 7 Pro   19999     4.4        35    73647
# 21      GIONEE          GIONEE Max    5499     4.1        31    51140
#
#     RAM( in gb)  ROM         color Top_Rating
# 182           6   64  Fusion Black       Good
# 256           2   32          Gray       Good
# 397           4  128   Matte Black       Good
# 205           6  128   Mirror Blue       Good
# 21            2   32           Red       Good

# %%
sns.scatterplot(x='Price',y='Discount',data=fivedis)
plt.show()

# %% [markdown]
# # Observation
# - SAMSUNG Galaxy F41 mobile have highest discount

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
fix, ax=plt.subplots(2,2,figsize=(12,12))
sns.distplot(fivedis['Price'], ax=ax[0,0])
sns.distplot(fivedis['Rating'], ax=ax[0,1])
sns.distplot(fivedis['Discount'], ax=ax[1,0])
sns.distplot(fivedis['Reviews'], ax=ax[1,1])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# # The five most costly moblie phones

# %%
data.nlargest(5, ['Price'])
# Out:
#     Brand_Name             Phone Name  Price  Rating  Discount  Reviews  \
# 373      APPLE       APPLE iPhone 12   81900     4.6         1     2030
# 347      APPLE       APPLE iPhone 12   76900     4.6         1     2028
# 354      APPLE       APPLE iPhone 12   76900     4.6        20     2028
# 351      APPLE  APPLE iPhone 12 Mini   70900     4.5         5      686
# 360      APPLE  APPLE iPhone 12 Mini   70900     4.5        16      687
#
#     RAM( in gb)  ROM  color Top_Rating
# 373           4  128   Blue       Good
# 347           0   64   Blue       Good
# 354           0   64  White       Good
# 351           3  128   Blue       Good
# 360           0  128  Black       Good

# %%
fivecostly=data.nlargest(5, ['Price'])

# %%
fivecostly
# Out:
#     Brand_Name             Phone Name  Price  Rating  Discount  Reviews  \
# 373      APPLE       APPLE iPhone 12   81900     4.6         1     2030
# 347      APPLE       APPLE iPhone 12   76900     4.6         1     2028
# 354      APPLE       APPLE iPhone 12   76900     4.6        20     2028
# 351      APPLE  APPLE iPhone 12 Mini   70900     4.5         5      686
# 360      APPLE  APPLE iPhone 12 Mini   70900     4.5        16      687
#
#     RAM( in gb)  ROM  color Top_Rating
# 373           4  128   Blue       Good
# 347           0   64   Blue       Good
# 354           0   64  White       Good
# 351           3  128   Blue       Good
# 360           0  128  Black       Good

# %%
sns.scatterplot(x='Price',y='Discount',data=fivedis)
plt.show()

# %% [markdown]
# # Observation
# - Highly costly phone is APPLE iPhone 12.Range(81000-70000)

# %%
fix, ax=plt.subplots(2,2,figsize=(12,12))
sns.distplot(fivecostly['Price'], ax=ax[0,0])
sns.distplot(fivecostly['Rating'], ax=ax[0,1])
sns.distplot(fivecostly['Discount'], ax=ax[1,0])
sns.distplot(fivecostly['Reviews'], ax=ax[1,1])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# # Top five high processing mobiles

# %%
data['RAM( in gb)'] = pd.to_numeric(data['RAM( in gb)'],errors = 'coerce')

# %%
highpro=data.nlargest(5, ["RAM( in gb)"])

# %%
highpro
# Out:
#    Brand_Name                    Phone Name  Price  Rating  Discount  Reviews  \
# 8      realme                     realme 7   15999     4.3        23    68985
# 28     realme                    realme 7i   12999     4.3        13   251537
# 37     realme  realme C15 Qualcomm Edition   10999     4.4        15    48736
# 38     realme                     realme 8   16999     4.5        10      641
# 39     realme                     realme 8   16999     4.5        10      683
#
#     RAM( in gb)  ROM         color Top_Rating
# 8             8  128     Mist Blue       Good
# 28            8  128  Fusion Green       Good
# 37            8   64  Power Silver       Good
# 38            8  128  Cyber Silver       Good
# 39            8  128  Cyber Silver       Good

# %% [markdown]
# # Observation
# - Realme7 and 8 phones have the highest processing power
# - As there are comimg with very afforable price so we can go with it and these are best choice for young generation

# %% [markdown]
# # Top high storage mobile phones

# %%
data['ROM'] = pd.to_numeric(data['ROM'],errors = 'coerce')

# %%
highstorage=data.nlargest(5, ["ROM"])

# %%
highstorage
# Out:
#     Brand_Name            Phone Name  Price  Rating  Discount  Reviews  \
# 100       IQOO               IQOO 3   32990     4.5        16   141385
# 374     realme  realme X3 SuperZoom   32999     4.3         5     2027
# 401      Apple      Apple iPhone SE   47999     4.5        12    95186
# 2         POCO              POCO M3   11999     4.3        20    71679
# 8       realme             realme 7   15999     4.3        23    68985
#
#      RAM( in gb)  ROM          color Top_Rating
# 100            8  256  Tornado Black       Good
# 374            6  256   Arctic White       Good
# 401            6  256          Black       Good
# 2              6  128    Power Black       Good
# 8              8  128      Mist Blue       Good

# %% [markdown]
# # Observation
# - IQOO 3,realme X3 SuperZoom and Apple iPhone SE are best phones having large ROMs.

# %% [markdown]
# # The five most cheaply mobile phones

# %%
most_cheap=data.nsmallest(5, ['Price'])

# %%
most_cheap
# Out:
#     Brand_Name        Phone Name  Price  Rating  Discount  Reviews  \
# 142     Salora       Salora Atom    609     3.8        16      417
# 176     Salora       Salora Atom    609     3.8        12      427
# 203      GFive       GFive U220+    618     3.5        20     3129
# 331    CALLBAR  CALLBAR Bold 312    620     3.7         7       11
# 384      GFive        GFive U106    643     3.7         2      396
#
#     RAM( in gb) ROM color Top_Rating
# 142           0   0   nan       Avg
# 176           0   0   nan       Avg
# 203           0   0   nan       Avg
# 331           0   0   nan       Avg
# 384           0   0   nan       Avg

# %% [markdown]
# # Observation
# - Most cheaply phone is Salora Atom Range(600-650).
# -

# %%
fix, ax=plt.subplots(2,2,figsize=(12,12))
sns.distplot(most_cheap['Price'], ax=ax[0,0])
sns.distplot(most_cheap['Rating'], ax=ax[0,1])
sns.distplot(most_cheap['Discount'], ax=ax[1,0])
sns.distplot(most_cheap['Reviews'], ax=ax[1,1])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# # The five most highest rated moblie phones

# %%
high_rated=data.nlargest(5, ['Rating'])

# %%
high_rated
# Out:
#     Brand_Name         Phone Name  Price  Rating  Discount  Reviews  \
# 267    Snexian  Snexian guru 5500    899     5.0         3        4
# 25       APPLE   APPLE iPhone 11   51999     4.6         5    41515
# 62       APPLE   APPLE iPhone 11   51999     4.6         5    41700
# 64       APPLE   APPLE iPhone 11   51999     4.6        20    41700
# 74       Apple   Apple iPhone XR   41999     4.6        21    78966
#
#     RAM( in gb) ROM   color Top_Rating
# 267           0   0     nan       Good
# 25            4  64   White       Good
# 62            8  64  Purple       Good
# 64            2  64   Black       Good
# 74            3  64   Black       Good

# %%
fix, ax=plt.subplots(2,2,figsize=(12,12))
sns.distplot(high_rated['Price'], ax=ax[0,0])
sns.distplot(high_rated['Rating'], ax=ax[0,1])
sns.distplot(high_rated['Discount'], ax=ax[1,0])
sns.distplot(high_rated['Reviews'], ax=ax[1,1])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# # The five most lowest rating moblie phones

# %%
lowest_rating=data.nsmallest(5, ['Rating'])

# %%
lowest_rating
# Out:
#     Brand_Name                                         Phone Name  Price  \
# 323       LAVA                                      LAVA Z61 Pro    5777
# 89        Nuvo  Nuvo 2.4" Display with 2500mAh Battery and Sel...    849
# 99        Nuvo                                         Nuvo FLASH    799
# 203      GFive                                        GFive U220+    618
# 353  BlackBear                             BlackBear A1 Pen Phone   1899
#
#      Rating  Discount  Reviews RAM( in gb) ROM           color Top_Rating
# 323     2.9        21      210           2  16  Champagne Gold       Avg
# 89      3.0        10        4           0   0             nan       Avg
# 99      3.5        28       75           0   0             nan       Avg
# 203     3.5        20     3129           0   0             nan       Avg
# 353     3.5        16      152           0   0             nan       Avg

# %% [markdown]
# # OBservation
# - Lowest rating phone is LAVA Z61 Pro having rating 2.9 .

# %%
fix, ax=plt.subplots(2,2,figsize=(12,12))
sns.distplot(lowest_rating['Price'], ax=ax[0,0])
sns.distplot(lowest_rating['Rating'], ax=ax[0,1])
sns.distplot(lowest_rating['Discount'], ax=ax[1,0])
sns.distplot(lowest_rating['Reviews'], ax=ax[1,1])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# # The five most moblie phones  having highest reviews

# %%
highest_rating=data.nlargest(5, ['Reviews'])

# %%
highest_rating
# Out:
#     Brand_Name        Phone Name  Price  Rating  Discount  Reviews  \
# 247     realme         realme 3    9499     4.5        20   452026
# 54      realme       realme C11    7499     4.4        15   415304
# 55      realme       realme C11    7499     4.4        20   415304
# 17      realme  realme Narzo 20   11499     4.3        17   370441
# 18      realme  realme Narzo 20   10499     4.3        19   370441
#
#     RAM( in gb)  ROM         color Top_Rating
# 247           3   64  Radiant Blue       Good
# 54            2   32    Rich Green       Good
# 55            2   32     Rich Grey       Good
# 17            4  128  Victory Blue       Good
# 18            4   64  Victory Blue       Good

# %% [raw]
# Realme mobiles have the highest reviews phones.

# %%
fix, ax=plt.subplots(2,2,figsize=(12,12))
sns.distplot(highest_rating['Price'], ax=ax[0,0])
sns.distplot(highest_rating['Rating'], ax=ax[0,1])
sns.distplot(highest_rating['Discount'], ax=ax[1,0])
sns.distplot(highest_rating['Reviews'], ax=ax[1,1])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# # The five most moblie phones having lowest reviews

# %%
lowest_rev=data.nsmallest(5,['Reviews'])

# %%
lowest_rev
# Out:
#     Brand_Name                                         Phone Name  Price  \
# 89        Nuvo  Nuvo 2.4" Display with 2500mAh Battery and Sel...    849
# 257    SAMSUNG                                SAMSUNG Galaxy A52   27999
# 267    Snexian                                  Snexian guru 5500    899
# 79       GFive                                         GFive U873    669
# 331    CALLBAR                                   CALLBAR Bold 312    620
#
#      Rating  Discount  Reviews RAM( in gb)  ROM         color Top_Rating
# 89      3.0        10        4           0    0           nan       Avg
# 257     3.8        20        4           8  128  Awesome Blue       Avg
# 267     5.0         3        4           0    0           nan       Good
# 79      3.7         9        7           0    0           nan       Avg
# 331     3.7         7       11           0    0           nan       Avg

# %% [markdown]
# # Observation
# - Its amazing to see SAMSUNG Galaxy A52.

# %%
fix, ax=plt.subplots(2,2,figsize=(12,12))
sns.distplot(lowest_rev['Price'], ax=ax[0,0])
sns.distplot(lowest_rev['Rating'], ax=ax[0,1])
sns.distplot(lowest_rev['Discount'], ax=ax[1,0])
sns.distplot(lowest_rev['Reviews'], ax=ax[1,1])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# # Null value

# %%
data.fillna(data.mean(),inplace=True)

# %%
data.dtypes
# Out:
# Brand_Name      object
# Phone Name      object
# Price            int64
# Rating         float64
# Discount         int64
# Reviews          int64
# RAM( in gb)     object
# ROM             object
# color           object
# Top_Rating      object
# dtype: object

# %%
data.isnull().sum()
# Out:
# Brand_Name     0
# Phone Name     0
# Price          0
# Rating         0
# Discount       0
# Reviews        0
# RAM( in gb)    0
# ROM            0
# color          0
# Top_Rating     0
# dtype: int64

# %% [markdown]
# # Data Visualization (Uni, Bi and Multi-variate)

# %% [markdown]
# # Ploting

# %% [raw]
#  Data Visualization (Uni, Bi and Multi-variate)
# Plot the every variable
# - Plots for Numerical and Categorical variables
# - Plots for Numerical to Categorical variable
# - Plots for Categorical to Numerical variables
# [Box-plot, Bar-plot, count plot, Pie chart, Scatter-plot, violin-plot,
# Distribution-plot, Heat map, Histogram and kde-plot etc., Use all plots for
# individual variables]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Bar plot

# %%
plt.bar(data['Rating'],data['Discount'],align="center",color='blue',edgecolor="orange",width=0.2 )
plt.title("Rating vs Discount",fontdict={'fontsize':20,'fontweight':25,'color':'green'})
plt.xlabel("Rating",fontdict={'fontsize':20,'fontweight':25,'color':'blue'})
plt.ylabel("Discount",fontdict={'fontsize':20,'fontweight':25,'color':'red'})
plt.show()

# %%
plt.bar(data['Price'],data['Rating'],align="center",color='blue',edgecolor="orange",width=1.2 )
plt.title("Price vs Rating ",fontdict={'fontsize':20,'fontweight':25,'color':'green'})
plt.xlabel("Price",fontdict={'fontsize':20,'fontweight':25,'color':'blue'})
plt.ylabel("Rating",fontdict={'fontsize':20,'fontweight':25,'color':'red'})
plt.show()

# %%
plt.bar(data['Price'],data['Discount'],align="center",color='blue',edgecolor="orange",width=1.2 )
plt.title("Price vs Discount",fontdict={'fontsize':20,'fontweight':25,'color':'green'})
plt.xlabel("Price",fontdict={'fontsize':20,'fontweight':25,'color':'blue'})
plt.ylabel("Discount",fontdict={'fontsize':20,'fontweight':25,'color':'red'})
plt.show()

# %% [markdown]
# # Box plot

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.boxplot([data["Price"],data["Rating"],data["Discount"]])
plt.xticks((1,2,3),["Price","Rating","Discount"])
plt.show()

# %%
plt.figure(dpi=100,figsize=(15,7))
sns.boxplot(x=data.Brand_Name,y=data.Price);

plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Count plot

# %%
sns.countplot(x="ROM",data=data)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Observation
# - There are a lot of mobiles which they dont have ROM.
# -  A lot of phones having 64gb storage are available in the market .

# %%
sns.countplot(x="RAM( in gb)",data=data)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Observation
# - 4gb ram phones are widely available in the market.
# - 6gb also

# %%
plt.figure(dpi=150,figsize=(20,7))
sns.countplot(x="color",data=data)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Observation
# - Black and blue colour phones are widely availavble in the market.

# %%
sns.countplot(x="Rating",data=data)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # observation:
# - here we can say that phones of 4.3 & 4.4 phones are highest in numbers.

# %%
plt.figure(dpi=100,figsize=(20,7))
sns.countplot(data.Brand_Name)
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Observation
# - Realme phones are in high numbers.

# %%
plt.figure(dpi=100,figsize=(10,7))
sns.countplot(data.Discount)
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(dpi=100,figsize=(30,7))
sns.countplot(data.Price)
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(dpi=100,figsize=(30,7))
sns.countplot(data.Reviews)
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(dpi=50,figsize=(20,5))
sns.countplot(data.Top_Rating)
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Pie chart

# %%
fivecostly
# Out:
#      Price  Rating  Discount  Reviews RAM( in gb)                  Brand  \
# 373  81900     4.6         1     2030         [4]       APPLE iPhone 12
# 347  76900     4.6         1     2028         NaN       APPLE iPhone 12
# 354  76900     4.6        20     2028         NaN       APPLE iPhone 12
# 351  70900     4.5         5      686         [3]  APPLE iPhone 12 Mini
# 360  70900     4.5        16      687         NaN  APPLE iPhone 12 Mini
#
#      color    ROM Top_Rating
# 373   Blue  [128]       Good
# 347   Blue   [64]       Good
# 354  White   [64]       Good
# 351   Blue  [128]       Good
# 360  Black  [128]       Good

# %%
country="india", "aus", "sli", "usa"
score="23","34","54","12"

# %%
pie=fivecostly["Rating"]

# %%
pie
# Out:
# 373    4.6
# 347    4.6
# 354    4.6
# 351    4.5
# 360    4.5
# Name: Rating, dtype: float64

# %%
# Out:
#   File "<ipython-input-148-da7b7389ce2b>", line 1
#     set()=uy
#     ^
# SyntaxError: cannot assign to function call

# %%
import matplotlib.pyplot as plt

labels=list(data["Brand_Name"])
fig1, ax1 = plt.subplots()
ax1.pie(list(data["Rating"]),labels=labels)
plt.show()

# %%
import matplotlib.pyplot as plt

labels=list(data["Phone Name"])
fig1, ax1 = plt.subplots()
ax1.pie(list(data["Rating"]),labels=labels)
plt.show()

# %%
plt.pie(data['Top_Rating'].value_counts(),labels=["Good","Average"],shadow=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x191be5a2760>,
# ...
#  [Text(-0.9942171299692213, 0.47067217729090877, 'Good'),
#   Text(0.9942171079354654, -0.47067222383357116, 'Average')])

# %%
data['Top_Rating'].value_counts()
# Out:
# Good    348
# Avg      57
# Name: Top_Rating, dtype: int64

# %%
data['Brand_Name'].unique()
# Out:
# array(['realme', 'POCO', 'REDMI', 'Redmi', 'Infinix', 'GIONEE', 'APPLE',
#        'GFive', 'Tecno', 'Apple', 'SAMSUNG', 'Nokia', 'Nuvo', 'MOTOROLA',
#        'IQOO', 'OPPO', 'LAVA', 'ViVO', 'Grabo', 'Salora', 'Micromax',
#        'Kechaoda', 'KARBONN', 'ENERGIZER', 'Snexian', 'Jio', 'Itel',
#        'Moto', 'MTR', 'Mi', 'GREENBERRI', 'Panasonic', 'Lava', 'I',
#        'Ismart', 'CALLBAR', 'Easyfone', 'BlackBear', 'BlackZone', 'Tork',
#        'Geotel'], dtype=object)

# %% [markdown]
# # Histograms

# %%
plt.hist(data["Rating"],bins=20,edgecolor='white')
plt.show()

# %%
plt.hist(data["Reviews"],bins=30,edgecolor='white')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
list(data["Rating"])
# Out:
# [4.4,
#  4.4,
#  4.3,
#  4.4,
#  4.3,
#  4.4,
#  4.3,
#  4.3,
#  4.3,
#  4.3,
#  4.3,
#  4.5,
#  4.5,
#  4.4,
#  4.4,
#  4.3,
#  4.3,
#  4.3,
#  4.3,
#  4.4,
#  4.3,
#  4.1,
#  4.1,
#  4.3,
#  4.3,
#  4.6,
#  4.3,
#  4.3,
#  4.3,
#  4.3,
#  4.1,
#  4.4,
#  4.4,
#  4.3,
#  4.3,
#  4.3,
#  4.4,
#  4.4,
#  4.5,
#  4.5,
#  4.5,
#  4.5,
#  3.7,
#  4.4,
#  4.3,
#  4.3,
#  4.4,
#  4.4,
#  3.8,
#  4.4,
#  4.4,
#  4.4,
#  3.6,
#  4.3,
#  4.4,
#  4.4,
#  4.3,
#  4.4,
#  4.4,
#  4.4,
#  4.4,
#  4.4,
#  4.6,
#  4.3,
#  4.6,
#  4.3,
#  4.4,
#  4.4,
#  4.4,
#  4.4,
#  4.4,
#  4.3,
#  4.4,
#  4.3,
#  4.6,
#  4.4,
#  4.4,
#  4.3,
#  4.3,
#  3.7,
#  4.4,
#  4.4,
#  4.3,
#  4.3,
#  4.3,
#  3.8,
#  4.4,
#  4.3,
#  4.3,
#  3.0,
#  4.1,
#  4.3,
#  4.4,
#  4.2,
#  4.4,
#  3.6,
#  4.3,
#  4.3,
#  4.3,
#  3.5,
#  4.5,
#  4.4,
#  4.4,
#  4.4,
#  4.4,
#  4.4,
#  4.4,
#  4.1,
#  4.2,
#  4.2,
#  4.3,
#  4.2,
#  4.3,
#  4.4,
#  4.0,
#  4.2,
#  3.8,
#  3.8,
#  4.3,
#  3.6,
#  4.2,
#  4.2,
#  4.6,
#  4.2,
#  4.2,
# ...

# %%
#data_price  =  data.groupby(by=['Brand']).mean()

# %%
fix, ax=plt.subplots(2,2,figsize=(12,12))
sns.distplot(data['Price'], ax=ax[0,0])
sns.distplot(data['Rating'], ax=ax[0,1])
sns.distplot(data['Discount'], ax=ax[1,0])
plt.xticks(rotation=90)


plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
fix, ax=plt.subplots(2,2,figsize=(12,12))
sns.distplot(data['Price'], ax=ax[0,0])
sns.distplot(data['Rating'], ax=ax[0,1])
sns.distplot(data['Discount'], ax=ax[1,0])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
sns.countplot(data.Discount,hue=data.Rating)
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.catplot(x='Price',kind='box',col='Top_Rating',hue='Top_Rating',aspect=0.7,data=data,height=3.8)
plt.show()

# %%
sns.catplot(x='Price',y='Discount',kind='swarm',col='Top_Rating',aspect=0.7,data=data)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 33.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 66.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 50.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 25.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
sns.scatterplot(x='Price',y='Discount',data=data,hue='Brand_Name')
plt.show()

# %%
sns.scatterplot(x='Brand_Name',y='Discount',data=data,hue='Price')
plt.show()

# %%
sns.pairplot(data,hue='Top_Rating')
plt.show()

# %%
sns.relplot(x='Discount',y='Price',hue='Top_Rating',data=data)
plt.xticks(rotation=90)
plt.show()

# %%
corrMat=data.corr()

# %%
sns.heatmap(corrMat, annot=True)
plt.show()

# %%
data.Top_Rating.unique()
# Out:
# array(['Good', 'Avg '], dtype=object)

# %%
data['Top_Rating'].value_counts()
# Out:
# Good    348
# Avg      57
# Name: Top_Rating, dtype: int64

# %%
import pandas as pd 

df = pd.DataFrame(["STD, City    State",
"33, Kolkata    West Bengal",
"44, Chennai    Tamil Nadu",
"40, Hyderabad    Telengana",
"80, Bangalore    Karnataka"], columns=['row'])

out = pd.DataFrame(df.row.str.split(' ',2).tolist(),columns=['STD','City','State'])
out.drop(index=0,inplace=True)

# %%
out

# %%
import pandas as pd

# %%
data1=pd.read_csv("kidney_disease.csv")

# %%
data1
# Out:
#       id   age    bp     sg   al   su     rbc        pc         pcc  \
# 0      0  48.0  80.0  1.020  1.0  0.0     NaN    normal  notpresent
# 1      1   7.0  50.0  1.020  4.0  0.0     NaN    normal  notpresent
# 2      2  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent
# 3      3  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present
# 4      4  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent
# ..   ...   ...   ...    ...  ...  ...     ...       ...         ...
# 395  395  55.0  80.0  1.020  0.0  0.0  normal    normal  notpresent
# 396  396  42.0  70.0  1.025  0.0  0.0  normal    normal  notpresent
# 397  397  12.0  80.0  1.020  0.0  0.0  normal    normal  notpresent
# 398  398  17.0  60.0  1.025  0.0  0.0  normal    normal  notpresent
# 399  399  58.0  80.0  1.025  0.0  0.0  normal    normal  notpresent
#
#              ba  ...  pcv    wc   rc  htn   dm  cad appet   pe  ane  \
# 0    notpresent  ...   44  7800  5.2  yes  yes   no  good   no   no
# ...

# %%
plt.figure(dpi=100,figsize=(20,7))
sns.countplot(data.Brand_Name )
plt.xticks(rotation=90)
plt.show()

# %%
sns.pairplot(data)
plt.show()

# %%
plt.figure(dpi=100,figsize=(15,7))
sns.boxplot(x=data.Brand_Name,y=data.Price);

plt.xticks(rotation=90)
plt.show()

# %%
sns.relplot(x='Brand_Name',y='Price',hue='top_rating',data=data)
plt.xticks(rotation=90)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-75335c50f373> in <module>
# ----> 1 sns.relplot(x='Brand_Name',y='Price',hue='top_rating',data=data)
#       2 plt.xticks(rotation=90)
#       3 plt.show()
#
# NameError: name 'sns' is not defined
